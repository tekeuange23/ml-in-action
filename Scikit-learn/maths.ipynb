# %%
###################################################################################################################
#                                       ''' The Normal Equation '''                                               #
###################################################################################################################
import numpy as np
import matplotlib.pyplot as plt

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

plt.scatter(X, y, alpha=0.5)
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
X_b = np.c_[np.ones((100, 1)), X] # add x0 = 1 to each instance
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new] # add x0 = 1 to each instance
y_predict = X_new_b.dot(theta_best)

plt.plot(X_new, y_predict, "r-")
plt.scatter(X, y, alpha=0.5)
plt.show()
# Out:
# [[4.07018237]
#  [2.97808524]]

# %%
###################################################################################################################
#                                       ''' LEAST SQUARE METHOD '''                                               #
###################################################################################################################
## (D): Y = aX + b  <=>  Mutiple combination of A(slope) and B(Intercept) are avaible 
##                  <=>  variate A make rotate (D) on a selected value of B (center or the rotation)
##                  <=>  variate B make translate (D) by a step A ()
##                  <=>  NB: the funtion f(x,y,z) = f(intercept, sumOfSquareResidual, slope)
##                           when derived by the intercept and the slope,
##                           "tells us where the optimal value are for the best fit." :StatQuest (08:16) 

# X_new = np.array([[0], [2]])
# X_new_b = np.c_[np.ones((2, 1)), X_new] # add x0 = 1 to each instance
# y_predict = X_new_b.dot(theta_best)
# plt.plot(X_new, y_predict, "r-")

for a in range(11):
    for b in range(11):
        X = np.array([[0], [20]])        # ZOOM: point used to plot
                                        # (D): Y = a.X1 + b.X0
        X_b = np.c_[np.ones((2, 1)), X] # add x0 = 1 to each instance
        Y = X_b.dot([[a], [b]])
        plt.plot(X, Y, "r-")

plt.axis([0, 20, 0, 20])
plt.plot(linewidth=2, markersize=12)

plt.show()
